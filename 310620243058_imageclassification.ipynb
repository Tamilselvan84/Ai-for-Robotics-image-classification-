# %% [markdown]
# # IMPORTING

# %%
import os
import warnings
warnings.simplefilter("ignore")
import numpy as np 
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage.io import imread,imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
df=os.listdir("C:/Users/Admin/Desktop/df")

# %%
pt=os.listdir("C:/Users/Admin/Desktop/pt")

# %%
limit=10
df_image=[None]*limit
j=0
for i in df:
    if(j<limit):
        df_image[j]=imread("C:/Users/Admin/Desktop/df/"+i)
        j+=1
    else:
        break

# %%
limit=10
pt_image=[None]*limit
j=0
for i in pt:
    if(j<limit):
        pt_image[j]=imread("C:/Users/Admin/Desktop/pt/"+i)
        j+=1
    else:
        break

# %%
imshow(df_image[1])

# %%
imshow(pt_image[1])

# %%
df_gray=[None]*limit

j=0

for i in df:

    if(j<limit):

        df_gray[j]=rgb2gray (df_image[j])

        j+=1

    else:

        break

# %%
pt_gray=[None]*limit

j=0

for i in pt:

    if(j<limit):

        pt_gray[j]=rgb2gray (pt_image[j])

        j+=1

    else:

        break

# %%
imshow(df_gray[1])

# %%
imshow(pt_gray[1])

# %%
df_gray[5].shape
# Out:
# (255, 197)

# %%
df_gray[2].shape
# Out:
# (259, 194)

# %%
for j in range(10):
    df = df_gray[j]
    df_gray[j] = resize(df,(512,512))

# %%
for j in range(10):
    pt = pt_gray[j]
    pt_gray[j] = resize(pt,(512,512))

# %%
imshow(pt_gray[1])

# %%
len_of_image_df = len(df_gray)

# %%
len_of_image_df
# Out:
# 10

# %%
len_of_image_pt = len(pt_gray)

# %%
len_of_image_pt
# Out:
# 10

# %%
image_size_df = df_gray[1].shape

# %%
flatten_size_df = image_size_df[0]* image_size_df[1]

# %%
flatten_size_df
# Out:
# 262144

# %%
for i in range(len_of_image_df):
    df_gray[i]=np.ndarray.flatten(df_gray[i]).reshape(flatten_size_df,1)

# %%
df_gray = np.dstack(df_gray)

# %%
df_gray = np.rollaxis(df_gray, axis = 2, start = 0 )

# %%
df_gray.shape
# Out:
# (10, 262144, 1)

# %%
df_gray = df_gray.reshape(len_of_image_df,flatten_size_df)

# %%
df_gray.shape
# Out:
# (10, 262144)

# %%
df_data = pd.DataFrame(df_gray)

# %%
df_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.070433  0.070433  0.070433  0.070433  0.070514  0.070831  0.071148
# 1  0.061522  0.061522  0.061522  0.061522  0.061522  0.061522  0.061522
# 2  0.100509  0.100509  0.100509  0.100509  0.100509  0.100509  0.100509
# 3  0.555116  0.555364  0.555021  0.554678  0.554022  0.552925  0.551828
# 4  0.046579  0.054535  0.043753  0.032972  0.023037  0.014409  0.005781
# 5  0.200437  0.200891  0.200133  0.199374  0.199326  0.199750  0.200172
# 6  0.078187  0.078187  0.078187  0.078187  0.078514  0.079591  0.080668
# 7  0.479656  0.477363  0.485684  0.492504  0.483514  0.474524  0.481128
# 8  0.025381  0.025381  0.025381  0.025381  0.025381  0.025381  0.025381
# 9  0.157596  0.157596  0.157596  0.157596  0.157658  0.158683  0.159707
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.071787  0.072856  0.073926  ...  0.024854  0.025923  0.026993  0.027451
# ...

# %%
df_data["label"] = "df"

# %%
df_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.070433  0.070433  0.070433  0.070433  0.070514  0.070831  0.071148
# 1  0.061522  0.061522  0.061522  0.061522  0.061522  0.061522  0.061522
# 2  0.100509  0.100509  0.100509  0.100509  0.100509  0.100509  0.100509
# 3  0.555116  0.555364  0.555021  0.554678  0.554022  0.552925  0.551828
# 4  0.046579  0.054535  0.043753  0.032972  0.023037  0.014409  0.005781
# 5  0.200437  0.200891  0.200133  0.199374  0.199326  0.199750  0.200172
# 6  0.078187  0.078187  0.078187  0.078187  0.078514  0.079591  0.080668
# 7  0.479656  0.477363  0.485684  0.492504  0.483514  0.474524  0.481128
# 8  0.025381  0.025381  0.025381  0.025381  0.025381  0.025381  0.025381
# 9  0.157596  0.157596  0.157596  0.157596  0.157658  0.158683  0.159707
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.071787  0.072856  0.073926  ...  0.025923  0.026993  0.027451  0.027451
# ...

# %%
image_size_pt = pt_gray[1].shape

# %%
flatten_size_pt = image_size_pt[0]* image_size_pt[1]

# %%
flatten_size_pt
# Out:
# 262144

# %%
for i in range(len_of_image_pt):
    pt_gray[i]=np.ndarray.flatten(pt_gray[i]).reshape(flatten_size_pt,1)

# %%
pt_gray = np.dstack(pt_gray)

# %%
pt_gray = np.rollaxis(pt_gray, axis = 2, start = 0 )

# %%
pt_gray.shape
# Out:
# (10, 262144, 1)

# %%
pt_gray = pt_gray.reshape(len_of_image_pt,flatten_size_pt)

# %%
pt_gray.shape
# Out:
# (10, 262144)

# %%
pt_data = pd.DataFrame(pt_gray)

# %%
pt_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.609145  0.608257  0.609773  0.611290  0.612942  0.614677  0.616459
# 1  0.620291  0.684030  0.584310  0.484589  0.407154  0.348607  0.290060
# 2  0.646217  0.646217  0.646217  0.646217  0.646217  0.646217  0.646217
# 3  0.218700  0.218700  0.218700  0.218700  0.218700  0.218700  0.218700
# 4  0.816809  0.816809  0.816809  0.816809  0.816809  0.816809  0.816809
# 5  0.569535  0.569535  0.569535  0.569535  0.569960  0.571362  0.572763
# 6  0.960845  0.960845  0.960845  0.960952  0.962193  0.963433  0.964059
# 7  0.272803  0.272803  0.272803  0.272803  0.273607  0.275093  0.276579
# 8  0.323909  0.393790  0.256716  0.119642  0.088769  0.096129  0.099881
# 9  0.022430  0.022430  0.022430  0.022430  0.022430  0.022430  0.022430
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.619492  0.622525  0.625511  ...  0.293291  0.271229  0.238257  0.205286
# ...

# %%
pt_data["label"] = "pt"

# %%
pt_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.609145  0.608257  0.609773  0.611290  0.612942  0.614677  0.616459
# 1  0.620291  0.684030  0.584310  0.484589  0.407154  0.348607  0.290060
# 2  0.646217  0.646217  0.646217  0.646217  0.646217  0.646217  0.646217
# 3  0.218700  0.218700  0.218700  0.218700  0.218700  0.218700  0.218700
# 4  0.816809  0.816809  0.816809  0.816809  0.816809  0.816809  0.816809
# 5  0.569535  0.569535  0.569535  0.569535  0.569960  0.571362  0.572763
# 6  0.960845  0.960845  0.960845  0.960952  0.962193  0.963433  0.964059
# 7  0.272803  0.272803  0.272803  0.272803  0.273607  0.275093  0.276579
# 8  0.323909  0.393790  0.256716  0.119642  0.088769  0.096129  0.099881
# 9  0.022430  0.022430  0.022430  0.022430  0.022430  0.022430  0.022430
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.619492  0.622525  0.625511  ...  0.271229  0.238257  0.205286  0.174862
# ...

# %% [markdown]
# # concat

# %%
fav_1 = pd.concat([df_data,pt_data])

# %%
fav_1
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.070433  0.070433  0.070433  0.070433  0.070514  0.070831  0.071148
# 1  0.061522  0.061522  0.061522  0.061522  0.061522  0.061522  0.061522
# 2  0.100509  0.100509  0.100509  0.100509  0.100509  0.100509  0.100509
# 3  0.555116  0.555364  0.555021  0.554678  0.554022  0.552925  0.551828
# 4  0.046579  0.054535  0.043753  0.032972  0.023037  0.014409  0.005781
# 5  0.200437  0.200891  0.200133  0.199374  0.199326  0.199750  0.200172
# 6  0.078187  0.078187  0.078187  0.078187  0.078514  0.079591  0.080668
# 7  0.479656  0.477363  0.485684  0.492504  0.483514  0.474524  0.481128
# 8  0.025381  0.025381  0.025381  0.025381  0.025381  0.025381  0.025381
# 9  0.157596  0.157596  0.157596  0.157596  0.157658  0.158683  0.159707
# 0  0.609145  0.608257  0.609773  0.611290  0.612942  0.614677  0.616459
# 1  0.620291  0.684030  0.584310  0.484589  0.407154  0.348607  0.290060
# ...

# %%
from sklearn.utils import shuffle

# %%
my_fav = shuffle(fav_1).reset_index()

# %%
my_fav
# Out:
#     index         0         1         2         3         4         5  \
# 0       9  0.157596  0.157596  0.157596  0.157596  0.157658  0.158683
# 1       8  0.323909  0.393790  0.256716  0.119642  0.088769  0.096129
# 2       4  0.816809  0.816809  0.816809  0.816809  0.816809  0.816809
# 3       8  0.025381  0.025381  0.025381  0.025381  0.025381  0.025381
# 4       9  0.022430  0.022430  0.022430  0.022430  0.022430  0.022430
# 5       6  0.960845  0.960845  0.960845  0.960952  0.962193  0.963433
# 6       1  0.620291  0.684030  0.584310  0.484589  0.407154  0.348607
# 7       5  0.200437  0.200891  0.200133  0.199374  0.199326  0.199750
# 8       5  0.569535  0.569535  0.569535  0.569535  0.569960  0.571362
# 9       0  0.609145  0.608257  0.609773  0.611290  0.612942  0.614677
# 10      3  0.555116  0.555364  0.555021  0.554678  0.554022  0.552925
# 11      3  0.218700  0.218700  0.218700  0.218700  0.218700  0.218700
# ...

# %% [markdown]
# # removing index

# %%
dream = my_fav.drop(['index'], axis = 1)

# %%
dream
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.157596  0.157596  0.157596  0.157596  0.157658  0.158683  0.159707
# 1   0.323909  0.393790  0.256716  0.119642  0.088769  0.096129  0.099881
# 2   0.816809  0.816809  0.816809  0.816809  0.816809  0.816809  0.816809
# 3   0.025381  0.025381  0.025381  0.025381  0.025381  0.025381  0.025381
# 4   0.022430  0.022430  0.022430  0.022430  0.022430  0.022430  0.022430
# 5   0.960845  0.960845  0.960845  0.960952  0.962193  0.963433  0.964059
# 6   0.620291  0.684030  0.584310  0.484589  0.407154  0.348607  0.290060
# 7   0.200437  0.200891  0.200133  0.199374  0.199326  0.199750  0.200172
# 8   0.569535  0.569535  0.569535  0.569535  0.569960  0.571362  0.572763
# 9   0.609145  0.608257  0.609773  0.611290  0.612942  0.614677  0.616459
# 10  0.555116  0.555364  0.555021  0.554678  0.554022  0.552925  0.551828
# 11  0.218700  0.218700  0.218700  0.218700  0.218700  0.218700  0.218700
# ...

# %%
x = dream.values[:,:-1]

# %%
y = dream.values[:,-1]

# %%
x
# Out:
# array([[0.15759553921568628, 0.15759553921568628, 0.15759553921568625,
#         ..., 1.0, 1.0, 1.0],
#        [0.32390913347431255, 0.3937900153246112, 0.25671597784902533,
#         ..., 0.0908877570657169, 0.08979522776884191, 0.0903522034888174],
#        [0.8168094117647058, 0.8168094117647058, 0.8168094117647058, ...,
#         0.3824307351579853, 0.26752684642567354, 0.32469853740467747],
#        ...,
#        [0.06152185661764706, 0.06152185661764706, 0.06152185661764706,
#         ..., 0.06437783088235295, 0.06437783088235294,
#         0.06437783088235295],
#        [0.47965560666776175, 0.47736269975774426, 0.48568373289893657,
#         ..., 0.21506557451061176, 0.25227257647720036,
#         0.24201998037974043],
#        [0.04657851899988511, 0.054534810647403495, 0.04375345892214308,
#         ..., 0.06724705882352942, 0.06724705882352942,
#         0.06724705882352942]], dtype=object)

# %%
y
# Out:
# array(['df', 'pt', 'pt', 'df', 'pt', 'pt', 'pt', 'df', 'pt', 'pt', 'df',
#        'pt', 'df', 'pt', 'df', 'df', 'pt', 'df', 'df', 'df'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size = 0.75, test_size = 0.25, random_state = 5)

# %%
x_train
# Out:
# array([[0.32390913347431255, 0.3937900153246112, 0.25671597784902533,
#         ..., 0.0908877570657169, 0.08979522776884191, 0.0903522034888174],
#        [0.21870021446078433, 0.21870021446078433, 0.21870021446078433,
#         ..., 0.02140335171568627, 0.020001697303921567,
#         0.02111995710784314],
#        [0.555115711071538, 0.5553639207069546, 0.5550208073874081, ...,
#         0.08014987888710172, 0.08700652046951593, 0.08204639677159926],
#        ...,
#        [0.10050941176470587, 0.10050941176470589, 0.10050941176470587,
#         ..., 0.0827278125, 0.0827278125, 0.0827278125],
#        [0.07043254901960784, 0.07043254901960784, 0.07043254901960783,
#         ..., 0.028003191480449604, 0.028319990868661916,
#         0.0280574499392042],
#        [0.025380784313725487, 0.025380784313725493, 0.02538078431372549,
#         ..., 0.2644225825171377, 0.2744445102945964, 0.2689598732024548]],
#       dtype=object)

# %%
x_test
# Out:
# array([[0.8168094117647058, 0.8168094117647058, 0.8168094117647058, ...,
#         0.3824307351579853, 0.26752684642567354, 0.32469853740467747],
#        [0.960844705882353, 0.960844705882353, 0.9608447058823529, ...,
#         0.6573314193729326, 0.6050292922640782, 0.6194414339562958],
#        [0.06152185661764706, 0.06152185661764706, 0.06152185661764706,
#         ..., 0.06437783088235295, 0.06437783088235294,
#         0.06437783088235295],
#        [0.04657851899988511, 0.054534810647403495, 0.04375345892214308,
#         ..., 0.06724705882352942, 0.06724705882352942,
#         0.06724705882352942],
#        [0.07818695542279414, 0.07818695542279414, 0.07818695542279414,
#         ..., 0.08125882352941176, 0.08125882352941176,
#         0.08125882352941176]], dtype=object)

# %%
y_train
# Out:
# array(['pt', 'pt', 'df', 'pt', 'df', 'df', 'pt', 'pt', 'pt', 'df', 'pt',
#        'pt', 'df', 'df', 'df'], dtype=object)

# %%
y_test
# Out:
# array(['pt', 'pt', 'df', 'df', 'df'], dtype=object)

# %%
from sklearn import svm

# %%
clf = svm.SVC()

# %%
clf.fit(x_train, y_train)
# Out:
# SVC()

# %% [markdown]
# # svm

# %%
y_pred = clf.predict(x_test)

# %%
y_pred
# Out:
# array(['pt', 'pt', 'df', 'df', 'pt'], dtype=object)

# %%
from sklearn import metrics

# %%
accuracy = metrics.accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.8

# %% [markdown]
# # error analysis

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[2, 1],
#        [0, 2]], dtype=int64)
